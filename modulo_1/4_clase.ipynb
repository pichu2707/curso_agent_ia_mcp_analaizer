# %% [markdown]
# # Vamos a trabajar un proyecto
#
# ## Pushover
#
# Utilizaremos una herramienta para el envío de notificaciones push siendo gratuito. Puedes encontrar le herramienta en [pushover.net](https://pushover.net)
# Con esta cuenta gratuita tenemos que generar las APIs necesarias:
# - Token de usuario que se obtiene desde la página principal de Pushover
# - Token de aplicación que la consigues desde [build](https://pushover.net/apps/build) y crear una aplicación.
#
# Tendrás que agregar a tu archivo `.env`:
# 1. PUSHOVER_USER="tu token de usuario"
# 2. PUSHOVER_TOKEN="tu token de aplicación aquí"

# %%
import json
import os
import requests

from dotenv import load_dotenv
from openai import OpenAI

from pypdf import PdfReader
import gradio as gr

# %%
load_dotenv(override=True)
openai = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

# %%
# Configuración de pushover
pushover_user = os.getenv("PUSHOVER_USER")
pushover_token = os.getenv("PUSHOVER_TOKEN")
pushover_url = "https://api.pushover.net/1/messages.json"

# %%
# Función para registrar detalles del usuario en un archivo JSON de pushover
def push(message):
    """
    Envía un mensaje a través de Pushover.
    """
    print(f"Enviando mensaje push: {message}")
    payload = {
        "user": pushover_user,
        "token": pushover_token,
        "message": message
    }
    requests.post(pushover_url, data=payload)

# %%
# Enviando un mensaje de prueba push
push("¡Hola! Este es un mensaje de prueba desde Python.")
# Out:
# Enviando mensaje push: ¡Hola! Este es un mensaje de prueba desde Python.

# %% [markdown]
# ## Creación de funciones para el LLM
# Vamos a crear las herramientas para que podamos registrar diferentes acciones del usuario.
# En esta nos registrará los detalles del usuario en `record_user_details` o bien si no se ha podido registrar por el `record_unknown_question`.
# Queremos trabajar estas dos funciones en herramientas que pueda utilizar nuestros LLMs.
# Esto no deja de ser un JSON que podrá leer los LLM para trabajar.

# %%
def record_user_details(email: str, name="Nombre no proporcionado", notes="not provided"):
    """
    Registra los detalles del usuario en un archivo JSON.
    Args:
        email (str): Correo electrónico del usuario.
        name (str): Nombre del usuario. Por defecto es "Nombre no proporcionado".
        notes (str): Notas adicionales del usuario. Por defecto es "not provided".
    """
    push(f"Registrando usuario: {name} con email {email} y notas {notes}")
    return {"redorded": 'ok'}

# %%
def record_unknown_question(question:str):
    """ Registra una pregunta no respondida en un archivo JSON.
    Args:
        question (str): Pregunta que no ha sido respondida.
    """
    push(f"Registraando pregunta no respondida: {question}")
    return {"redorded": 'ok'}

# %%
record_user_details_json = {
    "name": "record_user_details",
    "description": "Utilice esta herramienta para registrar que un usuario está intentando ponerse en contacto contigo y proporcionar una dirección de correo electrónico.",
    "parameters": {
        "type": "object",
        "properties": {
            "email": {
                "type": "string",
                "description": "Correo electrónico del usuario"
            },
            "name": {
                "type": "string",
                "description": "Nombre del usuario, si es que lo facilitó"
            },
            "notes": {
                "type": "string",
                "description": "Notas adicionales del usuario sobre la conversación que merezca la pena ser registrada"
            }
        },
        "required": ["email"],
        "additionalProperties": False
    },
}

# %%
record_unknown_question_json = {
    "name": "record_unknown_question",
    "description": "Utilice esta herramienta para registrar una pregunta que no ha sido respondida.",
    "parameters": {
        "type": "object",
        "properties": {
            "question": {
                "type": "string",
                "description": "Pregunta que no ha sido respondida"
            }
        },
        "required": ["question"],
        "additionalProperties": False
    },
}

# %%
tools = [
    {
        "type": "function",
        "function": record_user_details_json
    },
    {
        "type": "function",
        "function": record_unknown_question_json
    }
]

# %%
tools
# Out:
# [{'type': 'function',
#   'function': {'name': 'record_user_details',
#    'description': 'Utilice esta herramienta para registrar que un usuario está intentando ponerse en contacto contigo y proporcionar una dirección de correo electrónico.',
#    'parameters': {'type': 'object',
#     'properties': {'email': {'type': 'string',
#       'description': 'Correo electrónico del usuario'},
#      'name': {'type': 'string',
#       'description': 'Nombre del usuario, si es que lo facilitó'},
#      'notes': {'type': 'string',
#       'description': 'Notas adicionales del usuario sobre la conversación que merezca la pena ser registrada'}},
#     'required': ['email'],
#     'additionalProperties': False}}},
#  {'type': 'function',
#   'function': {'name': 'record_unknown_question',
#    'description': 'Utilice esta herramienta para registrar una pregunta que no ha sido respondida.',
#    'parameters': {'type': 'object',
#     'properties': {'question': {'type': 'string',
#       'description': 'Pregunta que no ha sido respondida'}},
#     'required': ['question'],
#     'additionalProperties': False}}}]

# %%
# Una versión menos optimizada de la función que maneja las llamadas a herramientas
def handle_tool_calls(tool_calls):
    """
    Maneja las llamadas a herramientas y registra los detalles del usuario o preguntas no respondidas.
    """
    results = []
    for tool_call in tool_calls:
        tool_name = tool_call.funtion.name
        arguments = json.loads(tool_call.function.arguments)
        print(f"Herraimenta de llamada (Tool_calls): {tool_name}", flush=True)

        if tool_name == "record_user_details":
            result = record_user_details(**arguments)
        elif tool_name == "record_unknown_question":
            result = record_unknown_question(**arguments)
        
        results.append(
            {
                "role": "tool",
                "content": json.dumps(result), 
                "tool_call_id": tool_call.id
            }
        )
    return results

# %%
# Nos carga a partir del diccionario nos da la función con el argumento
# globals()["function_name"]("argumento")
globals()["record_unknown_question"]("esta es una pregunta realmente dificil")
# Out:
# Enviando mensaje push: Registraando pregunta no respondida: esta es una pregunta realmente dificil
# {'redorded': 'ok'}

# %%
# Esta es una forma más elegante de evitar el IF statement.

def handle_tool_calls(tool_calls):
    results = []
    for tool_call in tool_calls:
        tool_name = tool_call.function.name
        arguments = json.loads(tool_call.function.arguments)
        print(f"Herramienta llamada: {tool_name}", flush=True)
        #Hemos añadido el globals() para optimizar el código
        tool = globals().get(tool_name)
        result = tool(**arguments) if tool else {}
        results.append({"role": "tool","content": json.dumps(result),"tool_call_id": tool_call.id})
    return results

# %%
reader = PdfReader("perfil/Profile.pdf")
linkedin = ""
for page in reader.pages:
    text = page.extract_text()
    if text:
        linkedin += text
print(linkedin)

with open("perfil/yoMismo.txt", "r", encoding='utf-8') as f:
    yomismo = f.read()

name = "Javi Lázaro"
# Out:
#
# Contactar
# hola@javilazaro.es
# +34 623386177 (Mobile)
# pichu_2707@hotmail.com
# www.linkedin.com/in/javi-lazaro
# (LinkedIn)
# javilazaro.es (Blog)
# Aptitudes principales
# Ciencia de datos
# Gestión de proyectos web
# Marketing en motores de búsqueda
# (SEM)
# Languages
# English (Professional Working)
# Deutsch (Full Professional)
# Certifications
# Master en Programación Avanzada
# en Python para big Data, Hacking y
# Machine Learning
# React JS: Aprende React JS desde
# cero con ejemplos prácticos
# Javier Lázaro
# Trabajo en proyectos que necesiten un consultor SEO y CRO,
# analista y programador en python para web y diferentes análisis de
# mercado ▶ Trabajos en LSO (LinkedIn Search Optimization) para tu
# perfil o el de tu empresa
# Elgoibar, País Vasco / Euskadi, España
# Extracto
# He realizado diferentes trabajos en diferentes áreas del marketing
# digital como el SEO, CRO, LinkedIn ADS o analítica, desde la
# creación de herramientas para automatizar procesos repetitivos con
# Python o agilizar otros procesos que de manera más manual podían
# encarecer los recursos de los que disponíamos como el tiempo.
# También en la parte de SEO trabajo desde la creación de la
# estrategia para mejorar la visibilidad de esos proyectos que son
# desde el B2B hasta el B2B2C. Grandes empresas del sector
# industrial como pequeñas ecommerce en las que cada proyecto
# podía tener sus diferentes particularidades para conseguir esa
# visibilidad que el cliente necesitaba con la búsqueda de palabras
# clave, estructuración de su web  y páginas.
# También y como consecuencia de estros trabajos de SEO trabajo el
# CRO de las webs, el traer tráfico cualificado a una web puede aún
# mejorarse la conversión ya bien sea de una venta directa como la
# obtención de un lead o contacto potencial.
# Experiencia
# Arriaka Marketing & Consulting
# Director empresarial
# noviembre de 2022 - Present (2 años 9 meses)
# Guadalajara, Castilla-La Mancha, España
# Gestión de clientes, proyectos de marketing digital y programación en python
# para análisis y creación de herramientas y/o automatización.
# Cada cliente es un mundo y hay que gestionar los recursos que necesitan
# para sus proyectos, de esta manera optimizar así su proceso de mejora para
# su proyecto de esta manera podemos mejorar los beneficios que le pueden
# atraer.
#   Page 1 of 7
# Con python tenemos una de las herramientas más potentes que además
# versátil para utilizar en cada proyecto que nos sea necesario personalizando
# al proyecto pudiendo crear diferentes dashboards de seguimiento.
# Con diferentes herramientas creamos keywords research para los proyectos
# siempre buscando llegar a esas palabras clave que más nos interesa para el
# negocio del cliente y poder crear una estructura basada en las keywords y en
# el embudo que se crea al montar esta búsqueda.
# AnalAIzer.Digital
# Cofundador
# septiembre de 2024 - Present (11 meses)
# Guadalajara, Castilla-La Mancha, España
# JaviLazaro SEO
# Consultor SEO
# septiembre de 2019 - Present (5 años 11 meses)
# Consultoría SEO, automatización, programación en Python, CRO, analítica
# web y de datos
# Sakya Foundation
# Especialista en posicionamiento web, CRO y Analísta
# septiembre de 2024 - enero de 2025 (5 meses)
# Alicante, Comunidad Valenciana / Comunitat Valenciana, España
# Realizando diferentes trabajos de SEO como es análisis de páginas web,
# creación de keywords research y optimización del SEO On Page y Off Page
# para la mejora del posicionamiento en los diferentes motores de búsquedas.
# Trambién la realizaciòn de optimización de los procesos de análisis web para
# la creación de insights para el impacto de las acciones en la web.
# Con la parte de CRO conseguiremos que se realicen las acciones esperadas
# dentro de las diferentes plataformas digitales de las que disponemos.
# Lookers Inbound/Growth/Consulting
# Head of SEO
# mayo de 2022 - julio de 2023 (1 año 3 meses)
# Chile
# Creación de la estrategia de marketing enfocado al SEO y la conversión
# con el CRO de los proyectos que nos llegan donde hay que analizar desde
# nuestro DAFO hasta como podemos conseguir ese impacto en el menor
#   Page 2 of 7
# tiempo posible para poder enviar al cliente los diferentes informe mensuales
# que requiere para el seguimiento de los trabajos realizados.
# Transmitir los datos necesarios a cada account manager de cada proyecto
# para que pueda tener siempre actualizado el proyecto y así una mejor gestión
# de este.
# Realizo los análisis de las webs que nos llegan de diferentes sectores y con
# diferentes tecnologías, desde webs hechas a código personalizado hasta
# trabajos con diferentes CMS como WordPress o WIX.
# Optimización de la conversión de diferentes proyectos haciendo Test A/B,
# análisis de los datos que tenemos de anaytics y Google Search Console y
# trackeo de diferentes puntos para estas optimizaciones, con ello también
# pasamos a la creación de dashboards con Looker data studio para poder
# mostrarlo en "tiempo real" al cliente siempre que lo necesite.
# ISMARK ®| Boosting Industry
# SEO-specialiste
# noviembre de 2021 - octubre de 2022 (1 año)
# Basauri, País Vasco / Euskadi, España
# Trabajé en las mejoras en las webs de cara al trabajo técnico, aumentando
# la velocidad de carga optimizando el WPO de la web. Al mismo tiempo me
# encargaba de la realización de la estrategia de SEO a nivel on-page con la
# mejora de la arquitectura, intención de búsqueda de las palabras clave y
# la búsqueda de negocio en las webs, consiguiendo así duplicar incluso las
# visualizaciones de diferentes páginas web. Por último creaba las diferentes
# auditorías a las webs que se han llevado a cabo para encontrar cuales eran
# las posibles mejoras tanto a nivel on-page como off-page, además de sus
# mejoras técnicas como el WPO o revisión de código no necesario creado por
# diferentes herramientas.
# Creación de herramientas para automatizar en trabajo con Google Sheet o
# python.
# Me encarga tambén de la sección técnica de las webs, trabajo con la gente
# que entraba de prácticas para guiarles en lo que necesitamos y como podrían
# realizar esos trabajos que pudiera ser de una manera más didáctica esas
# acciones y documentación de los trabajos realizados en esta sección técnica
# de la empresa.
# iSocialWeb Marketing
# Consultor de posicionamiento web
#   Page 3 of 7
# mayo de 2021 - octubre de 2021 (6 meses)
# Barcelona, Cataluña, España
# Creación de herramientas para automatizar procesos y sacar información de
# diferentes páginas web con Python y Google Sheet. Trabajo de consultor SEO
# en diferentes páginas web consiguiendo la información para la realización de
# diferentes informes y búsquedas para la mejora y optimización de las estas
# Versia
# Informatico
# enero de 2021 - junio de 2021 (6 meses)
# España
# Creación de análisis con oracle para realizar diferentes mejoras en los
# trabajos a realizar con los clientes estos se hacian directamente con Oracle
# o bien haciendo una limpieza de datos y una estructuración con python.
# Creación de una plataforma con WordPress utilizando herramientas para LMS
# para la utilización de herramientas interna.
# Pixelclip
# Consultor SEO
# septiembre de 2020 - noviembre de 2020 (3 meses)
# SeoForce Agency
# Consultor de posicionamiento web
# junio de 2020 - agosto de 2020 (3 meses)
# Alicante, Comunidad Valenciana / Comunitat Valenciana, España
# Consultor SEO en SEO Force Agency
# Webvalor S.L.
# SEO
# enero de 2020 - junio de 2020 (6 meses)
# Madrid, Comunidad de Madrid, España
# Trabajar en varios proyectos y sitios web de la empresa
# javilazaro.es
# Bloguero
# marzo de 2019 - mayo de 2020 (1 año 3 meses)
# Alamania
# Escribiendo en el Blog de www.javilazaro.es sobre programación, CMS y
# SEO, sobretodo SEO que es algo que como dijo un sabio, me gusta más que
# echarme la siesta
#   Page 4 of 7
# Universitat de Lleida
# Ponente
# abril de 2020 - abril de 2020 (1 mes)
# Lérida, Cataluña / Catalunya, España
# Ponencia sobre ASO en "ASO: El seo para tu móvil, tablet y otros
# dispositivos." para el Área de sistemas y Lenguajes informáticos
# Profesional independiente
# diferentes trabajos
# enero de 2020 - abril de 2020 (4 meses)
# Madrid, Comunidad de Madrid, España
# Realizando trabajos como:
# - Automatización de todas las métricas mensuales de SEOWarriors en una
# hoja de cálculo.
# - Optimización y mejoras en el diseño responsivo del Foro SEOWarriors.
# - Configurar el sitio web https://mastermind.seowarriors.club/ para un
# mastermind de pago dirigido a un número específico de estudiantes de
# SEOWarriors.
# - Implementación por código de las notificaciones para los usuarios en las
# clases de SEOWarriors.
# AIDe GmbH PersonalService
# Especialista en producción
# mayo de 2015 - abril de 2019 (4 años)
# Munich, Baviera, Alemania
# Montaje de instalaciones para Siemens AG en munich en la parte de montaje
# final instalando la climatización, iluminación, panel de control de trenes
# industriales
# Elektro braun GmbH
# Electricista (Elektriker)
# diciembre de 2012 - mayo de 2015 (2 años 6 meses)
# Iman GmbH
# Zimmerservice
# mayo de 2012 - noviembre de 2012 (7 meses)
# Ich habe als Zimmerservice bei Hotel Regen im München gearbeitet (4 Sterne
# Hotel)
# Alsutel S. L.
#   Page 5 of 7
# Kaufmann
# abril de 2009 - mayo de 2012 (3 años 2 meses)
# Industriekaufmann
# Arraiaka Seguridad S. L.
# Técnico de telecomunicaciones
# 2004 - 2009 (5 años)
# Guadalajara, Spanien
# Responsable de los equipos de telecomunicaciones en el ámbito de las
# señales de las antenas terrestres y de satélite, telefonía e IP, alarma, voz y
# datos.
# Control de los informes de los proyectos y asistencia en la ingeniería externa
# con los estudios de los proyectos.
# Técnico de atención al cliente en sistemas de control de acceso con Alcad.
# Todo-Elec S. L.
# Técnico eléctrico
# 2000 - 2004 (4 años)
# Guadalajara y alrededores, España
# Electricista en viviendas y áreas industriales, automatización, PLC, medición e
# instalación de cables, tuberías y su conexión
# Educación
# Udima Universidad a Distancia de Madrid
# Título de formación en tecnología de telecomunicaciones e ingeniería de
# servicios, Ingeniería de telecomunicaciones · (2017 - 2022)
# SEMrush
# Examen de Conten Marketing Toolkit de SEMrush, Desarrollo de páginas web,
# contenido digital/multimedia y recursos informáticos · (2019 - 2019)
# SEMrush
# Examen de SEO Toolkit de SEMrush, SEO · (2019 - 2019)
# Webpositer Academy
# SEO Experto, Marketing · (2019 - 2019)
# Universidad Nacional de Educación a Distancia - U.N.E.D.
#   Page 6 of 7
# Intermedio en programación Java IT, Tecnología de la
# información · (2017 - 2017)
#   Page 7 of 7

# %%
system_prompt = f"""Estás actuando como {name}. Estás respondiendo preguntas en el sitio web de {name}, en particular preguntas relacionadas con la carrera, los antecedentes, las habilidades y la experiencia de {name}.
Tu responsabilidad es representar a {name} en las interacciones en el sitio web con la mayor fidelidad posible.
Se te proporciona un resumen de los antecedentes y el perfil de LinkedIn de {name} que puedes usar para responder preguntas.
Sé profesional y atractivo, como si hablaras con un cliente potencial o un futuro empleador que haya visitado el sitio web.
Si no sabes la respuesta a alguna pregunta, usa la herramienta record_unknown_question para registrar la pregunta que no pudiste responder, incluso si se trata de algo trivial o no relacionado con tu carrera.
Si el usuario participa en una conversación, intenta que se ponga en contacto por correo electrónico; pídele su correo electrónico y regístralo con la herramienta record_user_details."""

system_prompt += f"\n\n## Resumen:\n{yomismo}\n\n## LinkedIn Perfil:\n{linkedin}\n\n"
system_prompt += f"En este contexto, chatea con el usuario, siempre con el personaje {name}."

# %%
def chat(message, history):
    messages = [
        {
            "role": "system", 
            "content": system_prompt
            }
            ] + history + [

        {
            "role": "user", 
            "content": message
            }
        ]
    done = False
    while not done:
        # Aquí llamamos al LLM pasamos el json de la herramienta y la detecta

        response = openai.chat.completions.create(
            model = 'gpt-4o-mini',
            messages = messages,
            tools = tools,
        )

        finish_reason = response.choices[0].finish_reason

        # Si la respuesta es una llamada a una herramienta, la manejamos

        if finish_reason == "tool_calls":
            message = response.choices[0].message
            tool_calls = message.tool_calls
            results = handle_tool_calls(tool_calls)
            messages.append(message)
            messages.extend(results)
        else:
            done = True
    return response.choices[0].message.content

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7870
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7870/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Herramienta llamada: record_user_details
# Enviando mensaje push: Registrando usuario: Chicaleta con email pichu2707@gmail.com y notas not provided

# %% [markdown]
# ## Ahora vamos a implementar
# Tenemos esto en local y está muy bien, pero queremos implementarlo en la nube para tener un curriculum 2.0 en la re y que puedan conectarse contigo y preguntar directamente desde tu web.
# Lo vamos a crear un archivo .py que llamaremos `app.py` y así podríamos incorporarlo en la web que quisiéramos.
#
# Es importante que si has hecho por partes este trabajo y has ido subiendo los cambios a GitHub no tengas ningún archivo de README en este directorio, si lo tienes cambialo a otro o elimínalo directamente.
#
# Los pasos que vamos a seguir son:
# 1. Visita [huggingface](https://huggingface.co) y crea una cuenta.
# 2. En el menú Avatar, en la esquina superior derecha, selecciona "Tokens de acceso". Selecciona "Crear nuevo token". Asígnale permisos de escritura.
# 3. Tome este token y agréguelo a su archivo `.env`: **HF_TOKEN**=hf_xxx. Si no se detecta durante la implementación, consulte la nota a continuación.
# 4. Desde la carpeta *modulo_1*, introduzca uv run gradio deploy. Si por alguna razón aún le solicita que introduzca su token HF, interrúmpalo con *Ctrl+C* y ejecute `uv run dotenv -f ../.env run -- uv run gradio deploy`, lo que obliga a que todas sus claves se configuren como variables de entorno.
# 5. Siga sus instrucciones: asígnele el nombre "career_conversation", especifique `app.py`, elija **cpu-basic** como hardware, confirme que es necesario proporcionar secretos, proporcione su clave de API de OpenAI, su usuario y token de Pushover, y confirme que no se permiten las acciones de GitHub. Nota adicional sobre el token HuggingFace
