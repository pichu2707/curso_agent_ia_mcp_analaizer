# %% [markdown]
# # Segunda clase
# En esta clase vamos a trabajar con más teconologías para ir conociendo diferentes APIs

# %% [markdown]
# ## 📦 Carga de librerías y configuración
#
# En esta celda importamos las librerías necesarias y cargamos las claves de API desde el archivo `.env`. Esto nos permite interactuar con los modelos de OpenAI, Anthropic (Claude) y Ollama de forma segura.
#
# Usamos `dotenv` para cargar las variables de entorno, y mostramos por consola los primeros caracteres de la clave disponible (sin exponer la clave completa).
#
# Esta configuración es esencial para autenticarnos correctamente con las APIs de los diferentes modelos.

# %%
import os
import json
import requests
from IPython.display import display, Markdown

from dotenv import load_dotenv
from openai import OpenAI
from anthropic import Anthropic

# %%
# Cargando el archivo .env de configuración
# Esto es necesario para que las variables de entorno se carguen correctamente
load_dotenv(override=True)
# Out:
# True

# %%
# Importando la clave de API de OpenAI desde las variables de entorno
openai_api_key = os.getenv("OPENAI_API_KEY")
anthropic_api_key = os.getenv("ANTHROPIC_API_KEY")

if openai_api_key and anthropic_api_key:
    print(f"La clave de API de OpenAI es: {openai_api_key[:5]}...")  # Mostrar solo los primeros 5 caracteres
    print(f"La clave de API de Anthropic es: {anthropic_api_key[:5]}...")
else:
    print("No se encontró ninguna clave de API en las variables de entorno.")
# Out:
# La clave de API de OpenAI es: sk-pr...
# La clave de API de Anthropic es: sk-an...

# %% [markdown]
# ## 🤖 Evaluación de modelos: respuestas generadas
#
# Con la pregunta generada, consultamos a tres modelos distintos:
#
# - `gpt-4o-mini` de OpenAI
# - `claude-3-7-sonnet-latest` de Anthropic
# - `llama3.2:latest` vía Ollama (local)
#
# Cada modelo responde a la misma pregunta, y las respuestas se almacenan en una lista para su posterior análisis.
#
# Mostramos la respuesta de cada modelo usando `Markdown` para facilitar la lectura.

# %%
request = "Vamos a hacer una petición a cada uno de los APIs que tenemos sobre analítica de datos, por favor hazme un pregunta para poder evaluar la respuesta de cada uno de los APIs por su inteligencia, responde únicamente con la pregunta sin explicaciones"
messages = [
    {
        "role": "user",
        "content": request
    }
]
print("messages:", messages)
# Out:
# messages: [{'role': 'user', 'content': 'Vamos a hacer una petición a cada uno de los APIs que tenemos sobre analítica de datos, por favor hazme un pregunta para poder evaluar la respuesta de cada uno de los APIs por su inteligencia, responde únicamente con la pregunta sin explicaciones'}]

# %%
messages
# Out:
# [{'role': 'user',
#   'content': 'Vamos a hacer una petición a cada uno de los APIs que tenemos sobre analítica de datos, por favor hazme un pregunta para poder evaluar la respuesta de cada uno de los APIs por su inteligencia, responde únicamente con la pregunta sin explicaciones'}]

# %% [markdown]
# Vamos a hacer una petición a cada uno de los APIs que tenemos

# %%
openai = OpenAI(api_key=openai_api_key)
response = openai.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages
)
question = response.choices[0].message.content
print("Pregunta generada por OpenAI:", question)
# Out:
# Pregunta generada por OpenAI: ¿Cuál es la tendencia de ventas en el último trimestre y qué factores podrían estar influyendo en ella?

# %%
competidores = []
answers = []
messages = [
    {
        "role": "user",
        "content": question
    }
]

# %%
messages
# Out:
# [{'role': 'user',
#   'content': '¿Cuál es la tendencia de ventas en el último trimestre y qué factores podrían estar influyendo en ella?'}]

# %%
model_name = "gpt-4o-mini"

response = openai.chat.completions.create(
    model=model_name,
    messages=messages
)

answer = response.choices[0].message.content
display(Markdown(f"**Respuesta de {model_name}:** {answer}"))
competidores.append(model_name)
answers.append(answer)
# Out:
# **Respuesta de gpt-4o-mini:** Para analizar la tendencia de ventas en el último trimestre y los factores que podrían estar influyendo en ella, es importante considerar varios aspectos:
#
# 1. **Datos de Ventas**: Examina las cifras de ventas del último trimestre en comparación con trimestres anteriores. Esto puede incluir ventas totales, por categoría de producto, y ventas en línea versus físicas.
#
# 2. **Estacionalidad**: El cuarto trimestre suele experimentar un aumento en las ventas debido a las festividades, como la Navidad y el Black Friday. La variación puede ser influenciada por estas compras estacionales.
#
# 3. **Cambios en el Comportamiento del Consumidor**: Factores como la confianza del consumidor, la disponibilidad de productos, y cambios en las preferencias pueden afectar las decisiones de compra. Por ejemplo, en tiempos de incertidumbre económica, los consumidores pueden optar por productos esenciales en lugar de lujosos.
#
# ...

# %%
model_name = "claude-opus-4-5-20251101"

claude = Anthropic(api_key=anthropic_api_key)
response = claude.messages.create(
    model=model_name,
    messages= messages,
    max_tokens=1000  # Ajusta el número de tokens según sea necesario
)

answer = response.content[0].text
display(Markdown(f"**Respuesta de {model_name}:** {answer}"))
competidores.append(model_name)
answers.append(answer)
# Out:
# **Respuesta de claude-opus-4-5-20251101:** # Análisis de Tendencias de Ventas
#
# No tengo acceso a datos específicos de ventas de tu empresa o contexto particular. Sin embargo, puedo ayudarte de dos maneras:
#
# ---
#
# ## Si me compartes tus datos, puedo ayudarte a:
#
# - Identificar patrones (crecimiento, estancamiento, caída)
# - Detectar estacionalidad
# - Comparar con períodos anteriores
# - Sugerir posibles causas
#
# ---
#
# ## Factores comunes que influyen en las ventas trimestrales:
#
# | **Categoría** | **Factores** |
# |---------------|--------------|
# | **Externos** | Economía general, inflación, competencia, estacionalidad |
# | **Internos** | Cambios de precio, nuevos productos, campañas de marketing |
# | **Operativos** | Disponibilidad de inventario, capacidad de entrega |
# | **Mercado** | Cambios en comportamiento del consumidor, nuevos competidores |
#
# ---
#
# ## ¿Qué información puedes compartirme?
#
# Para darte un análisis útil, sería ideal conocer:
#
# ...

# %%
model_name = "llama3.2:latest"
response = requests.post(
    "http://localhost:11434/api/generate",
    json={
        "model": model_name,
        "prompt": question
    }
)

# Ollama devuelve varias líneas JSON, una por chunk
respuesta = ""
for line in response.iter_lines():
    if line:
        data = json.loads(line)
        if "response" in data:
            respuesta += data["response"]

display(Markdown(f"**Respuesta de {model_name}:** {respuesta}"))
competidores.append(model_name)
answers.append(respuesta)
print(respuesta)
# Out:
# **Respuesta de llama3.2:latest:** No puedo proporcionar información sobre las tendencias actuales de ventas. Sin embargo, puedo ofrecerte algunos consejos generales para hacer frente a este problema.
#
# La tendencia de ventas puede variar según la industria, el mercado y la competencia. En general, es común que las ventas aumenten durante los trimestres finales debido a varios factores:
#
# 1.  **Aumento de la demanda**: Los consumidores tienden a comprar más durante los trimestres finales, ya sea para regalos o para satisfacer sus necesidades y deseos.
# 2.  **Promociones y descuentos**: Las empresas suelen ofrecer promociones y descuentos durante los trimestres finales para impulsar las ventas y atraer a nuevos clientes.
# 3.  **Nuevas tecnologías**: La publicación de nuevas tecnologías y productos puede crear una demanda más alta durante los trimestres finales.
# ...

# %%
together = ""
for index, answer in enumerate(answers):
    together += f"#Respuesta del competidor {index+1}\n\n"
    together += answer + "\n\n"

print(together)
# Out:
# #Respuesta del competidor 1
#
# Para analizar la tendencia de ventas en el último trimestre y los factores que podrían estar influyendo en ella, es importante considerar varios aspectos:
#
# 1. **Datos de Ventas**: Examina las cifras de ventas del último trimestre en comparación con trimestres anteriores. Esto puede incluir ventas totales, por categoría de producto, y ventas en línea versus físicas.
#
# 2. **Estacionalidad**: El cuarto trimestre suele experimentar un aumento en las ventas debido a las festividades, como la Navidad y el Black Friday. La variación puede ser influenciada por estas compras estacionales.
#
# 3. **Cambios en el Comportamiento del Consumidor**: Factores como la confianza del consumidor, la disponibilidad de productos, y cambios en las preferencias pueden afectar las decisiones de compra. Por ejemplo, en tiempos de incertidumbre económica, los consumidores pueden optar por productos esenciales en lugar de lujosos.
#
# ...

# %% [markdown]
# ## 📊 Comparativa de respuestas entre modelos
#
# En esta celda mostramos todas las respuestas generadas por los distintos modelos, impresas secuencialmente para facilitar la comparación humana.
#
# Esta sección sirve para revisar el desempeño de cada modelo antes de realizar una evaluación automatizada.

# %%
print(competidores)
# Out:
# ['gpt-4o-mini', 'claude-opus-4-5-20251101', 'llama3.2:latest']

# %% [markdown]
# ## 🧑‍⚖️ Evaluación automática del mejor modelo
#
# Pedimos a otro modelo de OpenAI (`o3-mini`) que actúe como juez.
#
# Le proporcionamos la pregunta original y todas las respuestas generadas, y le solicitamos que las clasifique de mejor a peor en función de:
#
# - Claridad
# - Precisión
# - Argumentación
#
# El modelo debe devolver un JSON con el ranking sin explicaciones ni formato adicional.

# %%
juez = f"""Vamos a evaluar las respuestas de los {len(competidores)} competidores, por favor responde únicamente con la respuesta de cada uno de los competidores sin explicaciones, a cada modelo se la ha dado la siguiente respuesta:
{question}

Tu trabajo será evaluar las respuestas por claridad y precisión además de un argumento más váildo y veraz.
Responde en formato JSON con la siguiente estructura:
{{"resultados: ["mejor competidor número 1", "segundo mejor competidor número 2", ...]}}
Aquí te dejo las respuestas de los competidores:
{together}
Ahora responde en JSON con el orden de clasificación sin formato markdown ni incluyendo conclusiones ni bloques de código"""
juez
# Out:
# 'Vamos a evaluar las respuestas de los 3 competidores, por favor responde únicamente con la respuesta de cada uno de los competidores sin explicaciones, a cada modelo se la ha dado la siguiente respuesta:\n¿Cuál es la tendencia de ventas en el último trimestre y qué factores podrían estar influyendo en ella?\n\nTu trabajo será evaluar las respuestas por claridad y precisión además de un argumento más váildo y veraz.\nResponde en formato JSON con la siguiente estructura:\n{"resultados: ["mejor competidor número 1", "segundo mejor competidor número 2", ...]}\nAquí te dejo las respuestas de los competidores:\n#Respuesta del competidor 1\n\nPara analizar la tendencia de ventas en el último trimestre y los factores que podrían estar influyendo en ella, es importante considerar varios aspectos:\n\n1. **Datos de Ventas**: Examina las cifras de ventas del último trimestre en comparación con trimestres anteriores. Esto puede incluir ventas totales, por categoría de producto, y ventas en línea
# ...

# %%
judge_messages = [
    {
        "role": "user",
        "content": juez
    }
]

# %% [markdown]
# ## ⚠️ Validación del ranking y fallback manual
#
# En esta última celda procesamos la respuesta del "juez".
#
# Si se extraen correctamente los números del ranking (ej: "1", "2", "3"), se imprime la clasificación en base a los índices.
#
# En caso de error o formato incorrecto, se muestra un mensaje para revisar manualmente la respuesta del modelo.
#
# Este paso garantiza robustez ante fallos en el análisis automático del JSON.

# %%
openai = OpenAI(api_key=openai_api_key)
response = openai.chat.completions.create(
    model="o3-mini",
    messages=judge_messages
)
resultados = response.choices[0].message.content
print("Resultados del juez:", resultados)
# Out:
# Resultados del juez: {"resultados": ["competidor 1", "competidor 3", "competidor 2"]}

# %%
print("=== LISTA DE RANKINGS ===")

# Buscar números en la respuesta del juez
import re
numeros_encontrados = re.findall(r'\d+', resultados)
print(f"Números encontrados en la respuesta del juez: {numeros_encontrados}")

if numeros_encontrados:
    print("\n🏆 RANKING FINAL DE MODELOS:")
    print("=" * 50)
    
    for index, num in enumerate(numeros_encontrados[:len(competidores)]):
        try:
            competidor_index = int(num) - 1
            if 0 <= competidor_index < len(competidores):
                competidor = competidores[competidor_index]
                print(f"🥇 Posición {index + 1}: {competidor}")
            else:
                print(f"⚠️  Posición {index + 1}: Número {num} fuera de rango")
        except (ValueError, IndexError):
            print(f"❌ Posición {index + 1}: Error procesando número {num}")
    
    print("=" * 50)
    print(f"📊 Total de competidores evaluados: {len(competidores)}")
    print(f"🎯 Números procesados: {len(numeros_encontrados[:len(competidores)])}")
    
else:
    print("❌ No se encontraron números válidos en la respuesta del juez")
    print("🔍 Revisa manualmente la respuesta del modelo:")
    print(f"Respuesta completa: {resultados}")
    
    # Mostrar lista de competidores para referencia manual
    print("\n📋 Lista de competidores para referencia:")
    for i, comp in enumerate(competidores):
        print(f"  {i+1}. {comp}")
# Out:
# === LISTA DE RANKINGS ===
# Números encontrados en la respuesta del juez: ['1', '3', '2']
#
# 🏆 RANKING FINAL DE MODELOS:
# ...
# 🥇 Posición 1: gpt-4o-mini
# 🥇 Posición 2: llama3.2:latest
# 🥇 Posición 3: claude-opus-4-5-20251101
# ...
# 📊 Total de competidores evaluados: 3
# 🎯 Números procesados: 3

# %%
# Verificar si Ollama está ejecutándose
import requests

try:
    response = requests.get("http://localhost:11434/api/tags")
    if response.status_code == 200:
        models = response.json()
        print("Ollama está ejecutándose. Modelos disponibles:")
        for model in models.get('models', []):
            print(f"- {model['name']}")
    else:
        print("Ollama no está respondiendo correctamente")
except Exception as e:
    print(f"No se puede conectar con Ollama: {e}")
    print("Asegúrate de ejecutar 'ollama serve' en la terminal")
# Out:
# Ollama está ejecutándose. Modelos disponibles:
# - llama3.1:latest
# - llama3.2:latest
# - gemma3:latest
