# %%
# Importando diferentes librerías
from dotenv import load_dotenv
import os

# Importando la librería OpenAI
from openai import OpenAI

# %%
# A continuación, es el momento de cargar las claves API en las veriables de entorno.
# override se utiliza para cargar variables de entorno desde un archivo .env
load_dotenv(override=True)
# Out:
# True

# %%
# Cargar la clave API de OpenAI desde las variables de entorno
openai_api_key = os.getenv("API_GPT")

# %%
# Vamos a revisar que todo está ok
if openai_api_key:
    print(f"Clave API cargada correctamente. Longitud de la clave: {len(openai_api_key)} caracteres.")
else:
    print("Error: No se pudo cargar la clave API. Asegúrate de que el archivo .env esté configurado correctamente.")
# Out:
# Clave API cargada correctamente. Longitud de la clave: 95 caracteres.

# %%
# Vamos a crear una instancia de OpenAI utilizando la clave API cargada
openai = OpenAI(api_key=openai_api_key)

# %%
# Creando una lista de mensajes para la conversación, esta la hacemos en el formato de diccionario para que OpenAI la entienda
messages = [
        {
            "role": "user",
            "content": "Hola, ¿cómo estás?"
        }
    ]

# %%
# Ahora vamos a probar nuestra conexión con OpenAI
response = openai.chat.completions.create(
    model="gpt-4.1-nano",
    messages=messages,
)
print(response.choices[0].message.content)
# Out:
# ¡Hola! Estoy bien, gracias. ¿Y tú? ¿En qué puedo ayudarte hoy?

# %%
# Ahora vamos a llamar a la API de OpenAI 
question = "Hay que poner una pregunta difícil sobre la analítica de datos web y el coeficinente de correlación de Pearson. Responde solo con la pregunta."
messages = [
    {
    "role": "user",
    "content": question
    }
]

# %%
response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages,
)

question = response.choices[0].message.content

print(response.choices[0].message.content)
# Out:
# ¿Cómo puede afectar la presencia de variables confusoras y la no linealidad en los datos web al interpretar el coeficiente de correlación de Pearson en un análisis de comportamiento de usuarios?

# %%
# Una nueva lista de mensajes para la conversación, esta la hacemos en el formato de diccionario para que OpenAI la entienda
messages = [
    {
        "role": "user",
        "content": question
    }
]

# %%
# Vamos a hacer una nueva pregunta a OpenAI
response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages,
)

answer = response.choices[0].message.content
print(f"Respuesta de OpenAI: {answer}")
# Out:
# Respuesta de OpenAI: La presencia de **variables confusoras** y la **no linealidad** en los datos web pueden afectar significativamente la interpretación del coeficiente de correlación de Pearson cuando se analiza el comportamiento de usuarios. Te explico cómo ocurre cada caso:
#
# ---
#
# ### 1. Variables Confusoras
#
# - **Qué son:** Son variables externas que influyen simultáneamente en las dos variables que se están correlacionando. Esto puede generar una asociación espuria, es decir, puede parecer que existe una relación directa cuando en realidad ambas variables están siendo afectadas por un tercer factor.
#
# - **Impacto en Pearson:**
#   - El coeficiente de Pearson mide la relación lineal directa entre dos variables, pero no controla por otros factores.
#   - Si existe una o más variables confusoras, la correlación puede estar sobreestimada o subestimada.
#   - Puede observarse una correlación significativa cuando en realidad la relación es indirecta o inexistente.
#   - Esto puede llevar a conclusiones erróneas sobre el comportamiento del usuario, por ejemplo, atribuir un efecto a una variable que en realidad está mediado por otra.
#
# - **Ejemplo:** Supongamos que se observa una correlación positiva entre el tiempo que un usuario pasa en una página y la tasa de conversión. Sin embargo, podría haber un confusor como la fuente de tráfico (usuarios provenientes de campañas específicas podrían pasar más tiempo y convertir más), y sin controlarlo, la correlación podría estar mal interpretada.
#
# ---
#
# ### 2. No Linealidad
#
# - **Qué es:** La relación real entre las variables puede no ser lineal (por ejemplo, puede ser cuadrática, exponencial, logística, etc.), pero el coeficiente de Pearson solo captura relaciones lineales.
#
# - **Impacto en Pearson:**
#   - En la presencia de relaciones no lineales fuertes, el coeficiente de Pearson puede ser cercano a cero, incluso cuando existe una relación clara entre las variables.
#   - Esto puede llevar a pensar erróneamente que no hay relación entre las variables, cuando en realidad sí la hay, pero de forma no lineal.
#   - Por lo tanto, el análisis puede subestimar la fuerza o tipo de relación entre comportamientos de usuario, perdiendo información valiosa.
#
# - **Ejemplo:** La satisfacción del usuario puede aumentar con el tiempo de uso de la aplicación hasta cierto punto, y luego caer (curva en forma de U invertida). Pearson podría mostrar baja correlación, aunque claramente el tiempo de uso influye en la satisfacción de forma no lineal.
#
# ---
#
# ### En resumen:
#
# | Factor                 | Impacto en Coeficiente de Pearson                      | Consecuencia en análisis de comportamiento de usuarios                 |
# |------------------------|------------------------------------------------------|-----------------------------------------------------------------------|
# | **Variables confusoras**| Correlación puede ser espuria o engañosa              | Conclusiones erróneas sobre relaciones causales                       |
# | **No linealidad**       | Pearson puede ser bajo o cercano a cero aunque hay relación | Subestimación o falta de detección de relaciones verdaderas           |
#
# ---
#
# ### Recomendaciones para mitigar estos problemas
#
# - **Controlar variables confusoras mediante análisis multivariado o técnicas de control estadístico** (e.g., regresión múltiple, modelos causales).
# - **Explorar la relación con gráficos de dispersión que permitan identificar patrones no lineales.**
# - **Usar otras métricas o métodos que capturen relaciones no lineales**, como el coeficiente de correlación de Spearman, o métodos basados en aprendizaje automático.
# - **Realizar análisis exploratorios antes de concluir** sólo con el coeficiente de Pearson.
#
# ---
#
# Espero que esta explicación te ayude a entender las limitaciones y precauciones necesarias al interpretar el coeficiente de correlación de Pearson en datos web con posibles variables confusoras y relaciones no lineales. ¿Quieres que te ayude con algún ejemplo aplicado o con técnicas específicas?
