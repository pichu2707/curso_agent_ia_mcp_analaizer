# %% [markdown]
# # Segunda clase
# En esta clase vamos a trabajar con más teconologías para ir conociendo diferentes APIs

# %% [markdown]
# ## 📦 Carga de librerías y configuración
#
# En esta celda importamos las librerías necesarias y cargamos las claves de API desde el archivo `.env`. Esto nos permite interactuar con los modelos de OpenAI, Anthropic (Claude) y Ollama de forma segura.
#
# Usamos `dotenv` para cargar las variables de entorno, y mostramos por consola los primeros caracteres de la clave disponible (sin exponer la clave completa).
#
# Esta configuración es esencial para autenticarnos correctamente con las APIs de los diferentes modelos.

# %%
import os
import json
import requests
from IPython.display import display, Markdown

from dotenv import load_dotenv
from openai import OpenAI
from anthropic import Anthropic

# %%
# Cargando el archivo .env de configuración
# Esto es necesario para que las variables de entorno se carguen correctamente
load_dotenv(override=True)
# Out:
# True

# %%
# Importando la clave de API de OpenAI desde las variables de entorno
openai_api_key = os.getenv("OPENAI_API_KEY")
anthropic_api_key = os.getenv("ANTHROPIC_API_KEY")

if openai_api_key:
    print(f"La clave de API de OpenAI es: {openai_api_key[:5]}...")  # Mostrar solo los primeros 5 caracteres
elif anthropic_api_key:
    print(f"La clave de API de Anthropic es: {anthropic_api_key[:5]}...")
else:
    print("No se encontró ninguna clave de API en las variables de entorno.")
# Out:
# La clave de API de OpenAI es: sk-pr...

# %% [markdown]
# ## 🤖 Evaluación de modelos: respuestas generadas
#
# Con la pregunta generada, consultamos a tres modelos distintos:
#
# - `gpt-4o-mini` de OpenAI
# - `claude-3-7-sonnet-latest` de Anthropic
# - `llama3.2:latest` vía Ollama (local)
#
# Cada modelo responde a la misma pregunta, y las respuestas se almacenan en una lista para su posterior análisis.
#
# Mostramos la respuesta de cada modelo usando `Markdown` para facilitar la lectura.

# %%
request = "Vamos a hacer una petición a cada uno de los APIs que tenemos sobre analítica de datos, por favor hazme un pregunta para poder evaluar la respuesta de cada uno de los APIs por su inteligencia, responde únicamente con la pregunta sin explicaciones"
messages = [
    {
        "role": "user",
        "content": request
    }
]
print("messages:", messages)
# Out:
# messages: [{'role': 'user', 'content': 'Vamos a hacer una petición a cada uno de los APIs que tenemos sobre analítica de datos, por favor hazme un pregunta para poder evaluar la respuesta de cada uno de los APIs por su inteligencia, responde únicamente con la pregunta sin explicaciones'}]

# %%
messages
# Out:
# [{'role': 'user',
#   'content': 'Vamos a hacer una petición a cada uno de los APIs que tenemos sobre analítica de datos, por favor hazme un pregunta para poder evaluar la respuesta de cada uno de los APIs por su inteligencia, responde únicamente con la pregunta sin explicaciones'}]

# %% [markdown]
# Vamos a hacer uan petición a cada uno de los APIs que tenemos

# %%
openai = OpenAI(api_key=openai_api_key)
response = openai.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages
)
question = response.choices[0].message.content
print("Pregunta generada por OpenAI:", question)
# Out:
# Pregunta generada por OpenAI: ¿Cuáles son las principales tendencias en analítica de datos para el próximo año?

# %%
competidores = []
answers = []
messages = [
    {
        "role": "user",
        "content": question
    }
]

# %%
messages
# Out:
# [{'role': 'user',
#   'content': '¿Cuáles son las principales tendencias en analítica de datos para el próximo año?'}]

# %%
model_name = "gpt-4o-mini"

response = openai.chat.completions.create(
    model=model_name,
    messages=messages
)

answer = response.choices[0].message.content
display(Markdown(f"**Respuesta de {model_name}:** {answer}"))
competidores.append(model_name)
answers.append(answer)
# Out:
# **Respuesta de gpt-4o-mini:** Las tendencias en analítica de datos están en constante evolución, y para el próximo año, algunas de las principales tendencias incluyen:
#
# 1. **Inteligencia Artificial y Aprendizaje Automático**: La integración de técnicas de IA y ML en la analítica de datos continuará creciendo, permitiendo la automatización de procesos, la mejora en la predicción de tendencias y la personalización de experiencias.
#
# 2. **Analítica en Tiempo Real**: La demanda de analítica en tiempo real seguirá aumentando, permitiendo a las organizaciones tomar decisiones instantáneas basadas en datos actualizados. Esto es especialmente relevante en sectores como fintech, comercio electrónico y atención médica.
#
# 3. **Ciencia de Datos Democrática**: Las herramientas de analítica se están volviendo más accesibles, lo que permite que no solo los científicos de datos, sino también otros profesionales, puedan extraer valor de los datos sin necesidad de conocimientos técnicos profundos.
#
# 4. **Automatización de la Ciencia de Datos**: La automatización en la recopilación, limpieza y modelado de datos se está volviendo crucial, permitiendo a los equipos de datos centrarse en aspectos más estratégicos en lugar de tareas repetitivas.
#
# 5. **Ética y Gobernanza de Datos**: A medida que aumenta la preocupación por la privacidad y la seguridad de los datos, las organizaciones deberán centrarse más en la ética y la gobernanza de los datos para cumplir con normativas y construir confianza con sus clientes.
#
# 6. **Analítica Predictiva y Prescriptiva**: La analítica no solo se centrará en entender qué ha sucedido (análisis descriptivo), sino que también se impulsará el uso de la analítica predictiva y prescriptiva para anticipar eventos futuros y sugerir acciones recomendadas.
#
# 7. **Visualización Avanzada de Datos**: Con el aumento de la complejidad de los datos, se espera que las herramientas de visualización evolucionen para ayudar a los usuarios a interpretar información de manera más efectiva y tomar decisiones más informadas.
#
# 8. **Integración de Datos de Fuentes Diversas**: La capacidad de integrar y analizar datos de múltiples fuentes, incluyendo datos no estructurados, será fundamental para obtener una visión más completa y holística del rendimiento organizacional.
#
# 9. **Cloud Analytics**: La migración hacia soluciones de análisis en la nube seguirá creciendo, permitiendo mayor flexibilidad, escalabilidad y colaboración en tiempo real.
#
# 10. **Analítica de Experiencias del Cliente**: Se pondrá un mayor énfasis en la analítica que se centra en la experiencia del cliente, utilizando datos para mejorar la interacción a lo largo del ciclo de vida del cliente y personalizar ofertas y servicios.
#
# Estas tendencias reflejan cómo las organizaciones están reconociendo la importancia de los datos en la toma de decisiones y cómo están adoptando tecnologías y estrategias para mejorar su capacidad analítica.

# %%
model_name = "claude-3-7-sonnet-latest"

claude = Anthropic(api_key=anthropic_api_key)
response = claude.messages.create(
    model=model_name,
    messages= messages,
    max_tokens=1000  # Ajusta el número de tokens según sea necesario
)

answer = response.content[0].text
display(Markdown(f"**Respuesta de {model_name}:** {answer}"))
competidores.append(model_name)
answers.append(answer)
# Out:
# **Respuesta de claude-3-7-sonnet-latest:** # Tendencias en analítica de datos para el próximo año
#
# Las principales tendencias que están marcando el futuro de la analítica de datos incluyen:
#
# ## Inteligencia Artificial y Aprendizaje Automático
# - Adopción generalizada de modelos de IA generativa para análisis predictivos
# - Democratización de herramientas de ML con interfaces "low-code/no-code"
# - Automatización de la preparación y limpieza de datos mediante IA
#
# ## Analítica en tiempo real
# - Procesamiento de datos de streaming para decisiones instantáneas
# - Integración con IoT y sistemas operativos empresariales
# - Dashboards dinámicos que se actualizan constantemente
#
# ## Data Mesh y arquitecturas descentralizadas
# - Cambio hacia modelos de propiedad de datos distribuidos
# - Tratamiento de datos como productos con responsables claros
# - Mayor autonomía para equipos específicos de dominio
#
# ## Ética de datos y privacidad
# - Frameworks robustos para el uso responsable de datos
# - Soluciones de privacidad diferencial y computación federada
# - Transparencia en modelos analíticos para cumplimiento normativo
#
# ## Analítica aumentada
# - Herramientas de autoservicio más sofisticadas para usuarios no técnicos
# - Interfaces conversacionales para consulta de datos
# - Explicabilidad mejorada de resultados analíticos complejos
#
# ¿Le interesa profundizar en alguna de estas tendencias en particular?

# %%
# Out:
# **Respuesta de llama3.2:latest:** Las tendencias en análisis de datos van evolucionando constantemente, y a continuación te presento algunas de las principales tendencias que se esperan ver en el próximo año:
#
# 1. **Análisis de voz**: La investigación de voz ha mejorado significativamente en últimas semanas. Esto significa que los analistas pueden procesar y analizar grandes cantidades de datos de voz con mayor rapidez y precisión, facilitando la toma de decisiones informadas.
# 2. **Lenguaje natural (NLP)**: La NLP continúa siendo una area clave del análisis de datos. Los modelos de aprendizaje profundo, como los BERT y GPT-3, están revolucionando el proceso de procesamiento de lenguaje natural, permitiendo a las empresas automatizar tareas complejas y generar respuestas personalizadas para sus clientes.
# 3. **Inteligencia artificial (IA) en marketing**: La IA se está convirtiendo cada vez más importante en marketing por sus capacidades para obtener patrones y relaciones significativas entre el comportamiento del consumidor y la información de negocio. Las empresas están utilizando modelos de aprendizaje profundo, como los clasificadores de redes neuronales y las métricas de algoritmos, para mejorar su comprensión de la audiencia.
# 4. **Big data**: La creciente demanda de datos por parte de las empresariales implica una necesidad cada vez mayor del "big data". Esto significa que se están utilizando herramientas de data science más avanzadas y tecnologías más sofisticadas para analizar y obtener valor de los datos que no se pueden manejar con métodos tradicionales.
# 5. **Clustering** de datos: Se estima que las empresas utilizarán Clúster en 2024, debido a su capacidad para unificar grandes cantidades de datos, permitiendo a las empresas tomar decisiones y resolver problemas mejor que nunca antes habían sido factibles con tecnologías actualmente disponibles.
# 6. **Visualización de datos**: El uso de visualizations de datos se está volviendo más importante por sus capacidades tanto visuales como de toma de decisione. Las empresas estarán utilizando herramientas como Matplotlib, Plotly y Tableau para crear interfaces visuales interactivas y compartir datos en presentaciones de manera efectiva.
# 7. **Blockchain** en Big Data: Esto es un área emergente que está ganando popularidad porque el almacenamiento seguro y respetuoso de grandes cantidades de datos es algo cada vez más importante.
#
# En resumen, para el próximo año, las tendencias en análisis de datos van a ser:
#
# * Análisis de voz
# * Lenguaje natural (NLP)
# * Inteligencia artificial (IA) en marketing
# * Big data
# * Clustering de datos
# * Visualización de datos
# * Blockchain en Big Data
#
# Estas tendencias son solo un par de las muchas que se están desarrollando y analizando en el mundo de análisis de datos.
#
# **¿Te gustaría saber más a cerca de alguna de estas tendencias?

# %%
together = ""
for index, answer in enumerate(answers):
    together += f"#Respuesta del competidor {index+1}\n\n"
    together += answer + "\n\n"

print(together)
# Out:
# Competidores: ['gpt-4o-mini', 'claude-3-7-sonnet-latest', 'llama3.2:latest']
# Respuestas: ['Las tendencias en analítica de datos están en constante evolución, y para el próximo año, algunas de las principales tendencias incluyen:\n\n1. **Inteligencia Artificial y Aprendizaje Automático**: La integración de técnicas de IA y ML en la analítica de datos continuará creciendo, permitiendo la automatización de procesos, la mejora en la predicción de tendencias y la personalización de experiencias.\n\n2. **Analítica en Tiempo Real**: La demanda de analítica en tiempo real seguirá aumentando, permitiendo a las organizaciones tomar decisiones instantáneas basadas en datos actualizados. Esto es especialmente relevante en sectores como fintech, comercio electrónico y atención médica.\n\n3. **Ciencia de Datos Democrática**: Las herramientas de analítica se están volviendo más accesibles, lo que permite que no solo los científicos de datos, sino también otros profesionales, puedan extraer valor de los datos sin necesidad de conocimientos técnicos profundos.\n\n4. **Automatización de la Ciencia de Datos**: La automatización en la recopilación, limpieza y modelado de datos se está volviendo crucial, permitiendo a los equipos de datos centrarse en aspectos más estratégicos en lugar de tareas repetitivas.\n\n5. **Ética y Gobernanza de Datos**: A medida que aumenta la preocupación por la privacidad y la seguridad de los datos, las organizaciones deberán centrarse más en la ética y la gobernanza de los datos para cumplir con normativas y construir confianza con sus clientes.\n\n6. **Analítica Predictiva y Prescriptiva**: La analítica no solo se centrará en entender qué ha sucedido (análisis descriptivo), sino que también se impulsará el uso de la analítica predictiva y prescriptiva para anticipar eventos futuros y sugerir acciones recomendadas.\n\n7. **Visualización Avanzada de Datos**: Con el aumento de la complejidad de los datos, se espera que las herramientas de visualización evolucionen para ayudar a los usuarios a interpretar información de manera más efectiva y tomar decisiones más informadas.\n\n8. **Integración de Datos de Fuentes Diversas**: La capacidad de integrar y analizar datos de múltiples fuentes, incluyendo datos no estructurados, será fundamental para obtener una visión más completa y holística del rendimiento organizacional.\n\n9. **Cloud Analytics**: La migración hacia soluciones de análisis en la nube seguirá creciendo, permitiendo mayor flexibilidad, escalabilidad y colaboración en tiempo real.\n\n10. **Analítica de Experiencias del Cliente**: Se pondrá un mayor énfasis en la analítica que se centra en la experiencia del cliente, utilizando datos para mejorar la interacción a lo largo del ciclo de vida del cliente y personalizar ofertas y servicios.\n\nEstas tendencias reflejan cómo las organizaciones están reconociendo la importancia de los datos en la toma de decisiones y cómo están adoptando tecnologías y estrategias para mejorar su capacidad analítica.', '# Tendencias en analítica de datos para el próximo año\n\nLas principales tendencias que están marcando el futuro de la analítica de datos incluyen:\n\n## Inteligencia Artificial y Aprendizaje Automático\n- Adopción generalizada de modelos de IA generativa para análisis predictivos\n- Democratización de herramientas de ML con interfaces "low-code/no-code"\n- Automatización de la preparación y limpieza de datos mediante IA\n\n## Analítica en tiempo real\n- Procesamiento de datos de streaming para decisiones instantáneas\n- Integración con IoT y sistemas operativos empresariales\n- Dashboards dinámicos que se actualizan constantemente\n\n## Data Mesh y arquitecturas descentralizadas\n- Cambio hacia modelos de propiedad de datos distribuidos\n- Tratamiento de datos como productos con responsables claros\n- Mayor autonomía para equipos específicos de dominio\n\n## Ética de datos y privacidad\n- Frameworks robustos para el uso responsable de datos\n- Soluciones de privacidad diferencial y computación federada\n- Transparencia en modelos analíticos p ...

# %% [markdown]
# ## 📊 Comparativa de respuestas entre modelos
#
# En esta celda mostramos todas las respuestas generadas por los distintos modelos, impresas secuencialmente para facilitar la comparación humana.
#
# Esta sección sirve para revisar el desempeño de cada modelo antes de realizar una evaluación automatizada.

# %%
print(competidores)
# Out:
# #Respuesta del competidor 1
#
# Las tendencias en analítica de datos están en constante evolución, y para el próximo año, algunas de las principales tendencias incluyen:
#
# 1. **Inteligencia Artificial y Aprendizaje Automático**: La integración de técnicas de IA y ML en la analítica de datos continuará creciendo, permitiendo la automatización de procesos, la mejora en la predicción de tendencias y la personalización de experiencias.
#
# 2. **Analítica en Tiempo Real**: La demanda de analítica en tiempo real seguirá aumentando, permitiendo a las organizaciones tomar decisiones instantáneas basadas en datos actualizados. Esto es especialmente relevante en sectores como fintech, comercio electrónico y atención médica.
#
# 3. **Ciencia de Datos Democrática**: Las herramientas de analítica se están volviendo más accesibles, lo que permite que no solo los científicos de datos, sino también otros profesionales, puedan extraer valor de los datos sin necesidad de conocimientos técnicos profundos.
#
# 4. **Automatización de la Ciencia de Datos**: La automatización en la recopilación, limpieza y modelado de datos se está volviendo crucial, permitiendo a los equipos de datos centrarse en aspectos más estratégicos en lugar de tareas repetitivas.
#
# 5. **Ética y Gobernanza de Datos**: A medida que aumenta la preocupación por la privacidad y la seguridad de los datos, las organizaciones deberán centrarse más en la ética y la gobernanza de los datos para cumplir con normativas y construir confianza con sus clientes.
#
# 6. **Analítica Predictiva y Prescriptiva**: La analítica no solo se centrará en entender qué ha sucedido (análisis descriptivo), sino que también se impulsará el uso de la analítica predictiva y prescriptiva para anticipar eventos futuros y sugerir acciones recomendadas.
#
# 7. **Visualización Avanzada de Datos**: Con el aumento de la complejidad de los datos, se espera que las herramientas de visualización evolucionen para ayudar a los usuarios a interpretar información de manera más efectiva y tomar decisiones más informadas.
#
# 8. **Integración de Datos de Fuentes Diversas**: La capacidad de integrar y analizar datos de múltiples fuentes, incluyendo datos no estructurados, será fundamental para obtener una visión más completa y holística del rendimiento organizacional.
#
# 9. **Cloud Analytics**: La migración hacia soluciones de análisis en la nube seguirá creciendo, permitiendo mayor flexibilidad, escalabilidad y colaboración en tiempo real.
#
# 10. **Analítica de Experiencias del Cliente**: Se pondrá un mayor énfasis en la analítica que se centra en la experiencia del cliente, utilizando datos para mejorar la interacción a lo largo del ciclo de vida del cliente y personalizar ofertas y servicios.
#
# Estas tendencias reflejan cómo las organizaciones están reconociendo la importancia de los datos en la toma de decisiones y cómo están adoptando tecnologías y estrategias para mejorar su capacidad analítica.
#
# #Respuesta del competidor 2
#
# # Tendencias en analítica de datos para el próximo año
#
# Las principales tendencias que están marcando el futuro de la analítica de datos incluyen:
#
# ## Inteligencia Artificial y Aprendizaje Automático
# - Adopción generalizada de modelos de IA generativa para análisis predictivos
# - Democratización de herramientas de ML con interfaces "low-code/no-code"
# - Automatización de la preparación y limpieza de datos mediante IA
#
# ## Analítica en tiempo real
# - Procesamiento de datos de streaming para decisiones instantáneas
# - Integración con IoT y sistemas operativos empresariales
# - Dashboards dinámicos que se actualizan constantemente
#
# ## Data Mesh y arquitecturas descentralizadas
# - Cambio hacia modelos de propiedad de datos distribuidos
# - Tratamiento de datos como productos con responsables claros
# - Mayor autonomía para equipos específicos de dominio
#
# ## Ética de datos y privacidad
# - Frameworks robustos para el uso responsable de datos
# - Soluciones de privacidad diferencial y computación federada
# - Transparencia en modelos analíticos para cumplimiento normativo
#
# ## Analítica aumentada
# - Herramientas de autoservicio más sofisticadas para usuarios no técnicos
# - Interfaces conversacionales para consulta de datos
# - Explicabilidad mejorada de resultados analíticos complejos
#
# ¿Le interesa profundizar en alguna de estas tendencias en particular?
#
# #Respuesta del competidor 3
#
# Las tendencias en análisis de datos van evolucionando constantemente, y a continuación te presento algunas de las principales tendencias que se esperan ver en el próximo año:
#
# 1. **Análisis de voz**: La investigación de voz ha mejorado significativamente en últimas semanas. Esto significa que los analistas pueden procesar y analizar grandes cantidades de datos de voz con mayor rapidez y precisión, facilitando la toma de decisiones informadas.
# 2. **Lenguaje natural (NLP)**: La NLP continúa siendo una area clave del análisis de datos. Los modelos de aprendizaje profundo, como los BERT y GPT-3, están revolucionando el proceso de procesamiento de lenguaje natural, permitiendo a las empresas automatizar tareas complejas y generar respuestas personalizadas para sus clientes.
# 3. **Inteligencia artificial (IA) en marketing**: La IA se está convirtiendo cada vez más importante en marketing por sus capacidades para obtener patrones y relaciones significativas entre el comportamiento del consumidor y la información de negocio. Las empresas están utilizando modelos de aprendizaje profundo, como los clasificadores de redes neuronales y las métricas de algoritmos, para mejorar su comprensión de la audiencia.
# 4. **Big data**: La creciente demanda de datos por parte de las empresariales implica una necesidad cada vez mayor del "big data". Esto significa que se están utilizando herramientas de data science más avanzadas y tecnologías más sofisticadas para analizar y obtener valor de los datos que no se pueden manejar con métodos tradicionales.
# 5. **Clustering** de datos: Se estima que las empresas utilizarán Clúster en 2024, debido a su capacidad para unificar grandes cantidades de datos, permitiendo a las empresas tomar decisiones y resolver problemas mejor que nunca antes habían sido factibles con tecnologías actualmente disponibles.
# 6. **Visualización de datos**: El uso de visualizations de datos se está volviendo más importante por sus capacidades tanto visuales como de toma de decisione. Las empresas estarán utilizando herramientas como Matplotlib, Plotly y Tableau para crear interfaces visuales interactivas y compartir datos en presentaciones de manera efectiva.
# 7. **Blockchain** en Big Data: Esto es un área emergente que está ganando popularidad porque el almacenamiento seguro y respetuoso de grandes cantidades de datos es algo cada vez más importante.
#
# En resumen, para el próximo año, las tendencias en análisis de datos van a ser:
#
# * Análisis de voz
# * Lenguaje natural (NLP)
# * Inteligencia artificial (IA) en marketing
# * Big data
# * Clustering de datos
# * Visualización de datos
# * Blockchain en Big Data
#
# Estas tendencias son solo un par de las muchas que se están desarrollando y analizando en el mundo de análisis de datos.
#
# **¿Te gustaría saber más a cerca de alguna de estas tendencias?

# %% [markdown]
# ## 🧑‍⚖️ Evaluación automática del mejor modelo
#
# Pedimos a otro modelo de OpenAI (`o3-mini`) que actúe como juez.
#
# Le proporcionamos la pregunta original y todas las respuestas generadas, y le solicitamos que las clasifique de mejor a peor en función de:
#
# - Claridad
# - Precisión
# - Argumentación
#
# El modelo debe devolver un JSON con el ranking sin explicaciones ni formato adicional.

# %%
juez = f"""Vamos a evaluar las respuestas de los {len(competidores)} competidores, por favor responde únicamente con la respuesta de cada uno de los competidores sin explicaciones, a cada modelo se la ha dado la siguiente respuesta:
{question}

Tu trabajo será evaluar las respuestas por claridad y precisión además de un argumento más váildo y veraz.
Responde en formato JSON con la siguiente estructura:
{{"resultados: ["mejor competidor número 1", "segundo mejor competidor número 2", ...]}}
Aquí te dejo las respuestas de los competidores:
{together}
Ahora responde en JSON con el orden de clasificación sin formato markdown ni incluyendo conclusiones ni bloques de código"""
juez
# Out:
# ['gpt-4o-mini', 'claude-3-7-sonnet-latest', 'llama3.2:latest']

# %%
judge_messages = [
    {
        "role": "user",
        "content": juez
    }
]

# %% [markdown]
# ## ⚠️ Validación del ranking y fallback manual
#
# En esta última celda procesamos la respuesta del "juez".
#
# Si se extraen correctamente los números del ranking (ej: "1", "2", "3"), se imprime la clasificación en base a los índices.
#
# En caso de error o formato incorrecto, se muestra un mensaje para revisar manualmente la respuesta del modelo.
#
# Este paso garantiza robustez ante fallos en el análisis automático del JSON.

# %%
openai = OpenAI(api_key=openai_api_key)
response = openai.chat.completions.create(
    model="o3-mini",
    messages=judge_messages
)
resultados = response.choices[0].message.content
print("Resultados del juez:", resultados)
# Out:
# Resultados del juez: {"resultados": ["mejor competidor número 1", "segundo mejor competidor número 3", "tercer competidor número 2"]}

# %%
print("=== LISTA DE RANKINGS ===")

# Buscar números en la respuesta del juez
import re
numeros_encontrados = re.findall(r'\d+', resultados)
print(f"Números encontrados en la respuesta del juez: {numeros_encontrados}")

if numeros_encontrados:
    print("\n🏆 RANKING FINAL DE MODELOS:")
    print("=" * 50)
    
    for index, num in enumerate(numeros_encontrados[:len(competidores)]):
        try:
            competidor_index = int(num) - 1
            if 0 <= competidor_index < len(competidores):
                competidor = competidores[competidor_index]
                print(f"🥇 Posición {index + 1}: {competidor}")
            else:
                print(f"⚠️  Posición {index + 1}: Número {num} fuera de rango")
        except (ValueError, IndexError):
            print(f"❌ Posición {index + 1}: Error procesando número {num}")
    
    print("=" * 50)
    print(f"📊 Total de competidores evaluados: {len(competidores)}")
    print(f"🎯 Números procesados: {len(numeros_encontrados[:len(competidores)])}")
    
else:
    print("❌ No se encontraron números válidos en la respuesta del juez")
    print("🔍 Revisa manualmente la respuesta del modelo:")
    print(f"Respuesta completa: {resultados}")
    
    # Mostrar lista de competidores para referencia manual
    print("\n📋 Lista de competidores para referencia:")
    for i, comp in enumerate(competidores):
        print(f"  {i+1}. {comp}")
# Out:
# === PROCESAMIENTO ALTERNATIVO ===
# Números encontrados en la respuesta del juez: ['2', '1', '3']
#
# 🏆 RANKING FINAL DE MODELOS:
# ==================================================
# 🥇 Posición 1: claude-3-7-sonnet-latest
# 🥇 Posición 2: gpt-4o-mini
# 🥇 Posición 3: llama3.2:latest
# ==================================================
# 📊 Total de competidores evaluados: 3
# 🎯 Números procesados: 3

# %%
# Verificar si Ollama está ejecutándose
import requests

try:
    response = requests.get("http://localhost:11434/api/tags")
    if response.status_code == 200:
        models = response.json()
        print("Ollama está ejecutándose. Modelos disponibles:")
        for model in models.get('models', []):
            print(f"- {model['name']}")
    else:
        print("Ollama no está respondiendo correctamente")
except Exception as e:
    print(f"No se puede conectar con Ollama: {e}")
    print("Asegúrate de ejecutar 'ollama serve' en la terminal")
# Out:
# Ollama está ejecutándose. Modelos disponibles:
# - llama3.2:latest
# - gemma3:latest

# %%
print("Competidores:", competidores)
print("Respuestas:", answers)
# Out:
# Competidores: ['gpt-4o-mini', 'claude-3-7-sonnet-latest', 'llama3.2:latest']
# Respuestas: ['Las tendencias en analítica de datos están en constante evolución, y para el próximo año, algunas de las principales tendencias incluyen:\n\n1. **Inteligencia Artificial y Aprendizaje Automático**: La integración de técnicas de IA y ML en la analítica de datos continuará creciendo, permitiendo la automatización de procesos, la mejora en la predicción de tendencias y la personalización de experiencias.\n\n2. **Analítica en Tiempo Real**: La demanda de analítica en tiempo real seguirá aumentando, permitiendo a las organizaciones tomar decisiones instantáneas basadas en datos actualizados. Esto es especialmente relevante en sectores como fintech, comercio electrónico y atención médica.\n\n3. **Ciencia de Datos Democrática**: Las herramientas de analítica se están volviendo más accesibles, lo que permite que no solo los científicos de datos, sino también otros profesionales, puedan extraer valor de los datos sin necesidad de conocimientos técnicos profundos.\n\n4. **Automatización de la Ciencia de Datos**: La automatización en la recopilación, limpieza y modelado de datos se está volviendo crucial, permitiendo a los equipos de datos centrarse en aspectos más estratégicos en lugar de tareas repetitivas.\n\n5. **Ética y Gobernanza de Datos**: A medida que aumenta la preocupación por la privacidad y la seguridad de los datos, las organizaciones deberán centrarse más en la ética y la gobernanza de los datos para cumplir con normativas y construir confianza con sus clientes.\n\n6. **Analítica Predictiva y Prescriptiva**: La analítica no solo se centrará en entender qué ha sucedido (análisis descriptivo), sino que también se impulsará el uso de la analítica predictiva y prescriptiva para anticipar eventos futuros y sugerir acciones recomendadas.\n\n7. **Visualización Avanzada de Datos**: Con el aumento de la complejidad de los datos, se espera que las herramientas de visualización evolucionen para ayudar a los usuarios a interpretar información de manera más efectiva y tomar decisiones más informadas.\n\n8. **Integración de Datos de Fuentes Diversas**: La capacidad de integrar y analizar datos de múltiples fuentes, incluyendo datos no estructurados, será fundamental para obtener una visión más completa y holística del rendimiento organizacional.\n\n9. **Cloud Analytics**: La migración hacia soluciones de análisis en la nube seguirá creciendo, permitiendo mayor flexibilidad, escalabilidad y colaboración en tiempo real.\n\n10. **Analítica de Experiencias del Cliente**: Se pondrá un mayor énfasis en la analítica que se centra en la experiencia del cliente, utilizando datos para mejorar la interacción a lo largo del ciclo de vida del cliente y personalizar ofertas y servicios.\n\nEstas tendencias reflejan cómo las organizaciones están reconociendo la importancia de los datos en la toma de decisiones y cómo están adoptando tecnologías y estrategias para mejorar su capacidad analítica.', '# Tendencias en analítica de datos para el próximo año\n\nLas principales tendencias que están marcando el futuro de la analítica de datos incluyen:\n\n## Inteligencia Artificial y Aprendizaje Automático\n- Adopción generalizada de modelos de IA generativa para análisis predictivos\n- Democratización de herramientas de ML con interfaces "low-code/no-code"\n- Automatización de la preparación y limpieza de datos mediante IA\n\n## Analítica en tiempo real\n- Procesamiento de datos de streaming para decisiones instantáneas\n- Integración con IoT y sistemas operativos empresariales\n- Dashboards dinámicos que se actualizan constantemente\n\n## Data Mesh y arquitecturas descentralizadas\n- Cambio hacia modelos de propiedad de datos distribuidos\n- Tratamiento de datos como productos con responsables claros\n- Mayor autonomía para equipos específicos de dominio\n\n## Ética de datos y privacidad\n- Frameworks robustos para el uso responsable de datos\n- Soluciones de privacidad diferencial y computación federada\n- Transparencia en modelos analíticos p ...
